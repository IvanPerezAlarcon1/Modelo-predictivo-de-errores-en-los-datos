# %%
import pandas as pd
import os

# %%
def det_extension_file(archivo):
    name_file, extension_file = os.path.splitext(archivo)
    return name_file, extension_file

# %%
archivo = r'C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\hotel_bookings_1.csv'
var1, var2 = det_extension_file(archivo)
var1, var2
# Out:
# ('C:\\Users\\ivan1\\Desktop\\Modelo-predictivo-de-errores-en-los-datos\\hotel_bookings_1',
#  '.csv')

# %%
file = r'C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\hotel_bookings_1_NGRAMS-test-2-cols--witherrors.csv'
v1,v2 = det_extension_file(file)
v1,v2
# Out:
# ('C:\\Users\\ivan1\\Desktop\\Modelo-predictivo-de-errores-en-los-datos\\DESARROLLO\\hotel_bookings_1_NGRAMS-test-2-cols--witherrors',
#  '.csv')

# %%
def dataframe_from_file(archivo):
    aux1 , aux2 = os.path.splitext(archivo)
    if (aux2) == '.csv':
        dataframe = pd.read_csv(archivo)
    if (aux2) == '.xlsx':
        dataframe = pd.read_excel(archivo)
    return dataframe

# %%
def dataframe_from_file_sep(archivo,separador):
    aux1, aux2 =  os.path.splitext(archivo)
    if (aux2) == '.csv':
        dataframe = pd.read_csv(archivo,sep = separador)
    if(aux2) == '.xlsx':
        dataframe = pd.read_excel(archivo)
    return dataframe

# %%
dftest = dataframe_from_file_sep(r"C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\DATASETS PRUEBAS\hotel_bookings_25000 - NULLS CORRECCION.csv",',')
dftest
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Htel            0        342               2015
# 1       rsort Hotel            0        737               2015
# 2          Cty otel            0          7               2015
# 3         city hotl            0         13               2015
# 4         CITY HTEL            0         14               2015
# ...             ...          ...        ...                ...
# 24995  Resort Hotel            0          4               2016
# 24996  Resort Hotel            0         44               2016
# 24997  Resort Hotel            0         44               2016
# 24998  Resort Hotel            0        118               2016
# 24999  Resort Hotel            0         96               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   Juli                      27.0                          1
# ...

# %%
dftest2 = dataframe_from_file_sep(r'C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\DATASETS PRUEBAS\hotel_bookings_25000 - NULLS CORRECCION  testsep.csv',';')
dftest2
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Htel            0        342               2015
# 1       rsort Hotel            0        737               2015
# 2          Cty otel            0          7               2015
# 3         city hotl            0         13               2015
# 4         CITY HTEL            0         14               2015
# ...             ...          ...        ...                ...
# 24995  Resort Hotel            0          4               2016
# 24996  Resort Hotel            0         44               2016
# 24997  Resort Hotel            0         44               2016
# 24998  Resort Hotel            0        118               2016
# 24999  Resort Hotel            0         96               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   Juli                      27.0                          1
# ...

# %%
dftest3 = dataframe_from_file_sep(r'C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\hotel_bookings_1_NGRAMS-test.xlsx','')
dftest3
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df = dataframe_from_file(archivo)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data_test = pd.read_csv(r'C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\DATASETS PRUEBAS\hotel_bookings_25000 - NULLS CORRECCION  testsep.csv', sep=';')

# %%
data_test
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Htel            0        342               2015
# 1       rsort Hotel            0        737               2015
# 2          Cty otel            0          7               2015
# 3         city hotl            0         13               2015
# 4         CITY HTEL            0         14               2015
# ...             ...          ...        ...                ...
# 24995  Resort Hotel            0          4               2016
# 24996  Resort Hotel            0         44               2016
# 24997  Resort Hotel            0         44               2016
# 24998  Resort Hotel            0        118               2016
# 24999  Resort Hotel            0         96               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   Juli                      27.0                          1
# ...

# %%
data_test1 = pd.read_csv(r"C:\Users\ivan1\Desktop\Modelo-predictivo-de-errores-en-los-datos\DESARROLLO\DATASETS PRUEBAS\hotel_bookings_25000 - NULLS CORRECCION.csv", sep = ',')

# %%
data_test1
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Htel            0        342               2015
# 1       rsort Hotel            0        737               2015
# 2          Cty otel            0          7               2015
# 3         city hotl            0         13               2015
# 4         CITY HTEL            0         14               2015
# ...             ...          ...        ...                ...
# 24995  Resort Hotel            0          4               2016
# 24996  Resort Hotel            0         44               2016
# 24997  Resort Hotel            0         44               2016
# 24998  Resort Hotel            0        118               2016
# 24999  Resort Hotel            0         96               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   Juli                      27.0                          1
# ...

# %%
df.loc[:,'hotel'] == 'Resort Hotel'
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: hotel, Length: 119390, dtype: bool

# %%
df.loc[df.loc[:,'hotel'] == 'Resort Hotel']
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# 5      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.groupby(["hotel"]).size()
# Out:
# hotel
# City Hotel       79330
# Resort Htel          1
# Resorte Hotel        1
# hola             40058
# dtype: int64

# %%
df["hotel"] = df["hotel"].str.replace("Resort Hotel","hola")

# %%
df
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0              hola            0        342               2015
# 1       Resort Htel            0        737               2015
# 2              hola            0          7               2015
# 3              hola            0         13               2015
# 4              hola            0         14               2015
# ...             ...          ...        ...                ...
# 119385   City Hotel            0         23               2017
# 119386   City Hotel            0        102               2017
# 119387   City Hotel            0         34               2017
# 119388   City Hotel            0        109               2017
# 119389   City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df[df.columns["hotel"]] = df[df.columns["hotel"]].replace(to_replace = 'Resort Hotel', value = 'HOLA')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-722de913cb6a> in <module>
# ----> 1 df[df.columns["hotel"]] = df[df.columns["hotel"]].replace(to_replace = 'Resort Hotel', value = 'HOLA')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df[df_string.columns[col_string_name]] = df[df_string.columns[col_string_name]].replace(to_replace = l,  value = VAR1)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['hotel'] = df['hotel'].replace(to_replace = 'City Hotel', value = 'nuevo')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385         nuevo            0         23               2017
# 119386         nuevo            0        102               2017
# 119387         nuevo            0         34               2017
# 119388         nuevo            0        109               2017
# 119389         nuevo            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.columns[0]
# Out:
# 'hotel'

# %% [markdown]
# # MODA

# %%
import statistics as stat

edades = [21, 17, 89, 76, 32, 21, 45, 21, 89, 21, 15, 89, 21]

moda=stat.mode(edades)

print(moda)
# Out:
# 21

# %%
hotel = df["hotel"]
hotel
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
hotel_moda = stat.mode(hotel)
hotel_moda
# Out:
# 'City Hotel'

# %%
df["hotel"].mode()[0]
# Out:
# 'City Hotel'

# %%
modas_df = {}
modas_df.setdefault('COLUMNAS',[])
modas_df.setdefault('MODA',[])
# Out:
# []

# %%
for i in range(len(df.columns)):
    print("Columna",i,":",df.columns[i], )
          #," Moda: ", stat.mode(df[df.columns[i]]))
# Out:
# Columna 0 : hotel
# Columna 1 : is_canceled
# Columna 2 : lead_time
# Columna 3 : arrival_date_year
# Columna 4 : arrival_date_month
# Columna 5 : arrival_date_week_number
# Columna 6 : arrival_date_day_of_month
# Columna 7 : stays_in_weekend_nights
# Columna 8 : stays_in_week_nights
# Columna 9 : adults
# Columna 10 : children
# Columna 11 : babies
# Columna 12 : meal
# Columna 13 : country
# Columna 14 : market_segment
# Columna 15 : distribution_channel
# Columna 16 : is_repeated_guest
# Columna 17 : previous_cancellations
# Columna 18 : previous_bookings_not_canceled
# Columna 19 : reserved_room_type
# Columna 20 : assigned_room_type
# Columna 21 : booking_changes
# Columna 22 : deposit_type
# Columna 23 : agent
# Columna 24 : company
# Columna 25 : days_in_waiting_list
# Columna 26 : customer_type
# Columna 27 : adr
# Columna 28 : required_car_parking_spaces
# Columna 29 : total_of_special_requests
# Columna 30 : reservation_status
# Columna 31 : reservation_status_date

# %%
for i in range(len(df.columns)):
    print("Columna",i,":",df.columns[i], df[df.columns[i]].mode()[0])
# Out:
# Columna 0 : hotel City Hotel
# Columna 1 : is_canceled 0
# Columna 2 : lead_time 0
# Columna 3 : arrival_date_year 2016
# Columna 4 : arrival_date_month August
# Columna 5 : arrival_date_week_number 33
# Columna 6 : arrival_date_day_of_month 17
# Columna 7 : stays_in_weekend_nights 0
# Columna 8 : stays_in_week_nights 2
# Columna 9 : adults 2
# Columna 10 : children 0.0
# Columna 11 : babies 0
# Columna 12 : meal BB
# Columna 13 : country PRT
# Columna 14 : market_segment Online TA
# Columna 15 : distribution_channel TA/TO
# Columna 16 : is_repeated_guest 0
# Columna 17 : previous_cancellations 0
# Columna 18 : previous_bookings_not_canceled 0
# Columna 19 : reserved_room_type A
# Columna 20 : assigned_room_type A
# Columna 21 : booking_changes 0
# Columna 22 : deposit_type No Deposit
# Columna 23 : agent 9.0
# Columna 24 : company 40.0
# Columna 25 : days_in_waiting_list 0
# Columna 26 : customer_type Transient
# Columna 27 : adr 62.0
# Columna 28 : required_car_parking_spaces 0
# ...

# %% [markdown]
# # VALORES MAX,MIN,MEDIA,MEDIANA,CURTOSIS DE COLUMNAS NUMERICAS

# %%
for i in range(len(df.columns)):
    #print(df.columns[i], " - ", df[df.columns[i]].dtype.name)
    if(df[df.columns[i]].dtype.name == 'int64' or df[df.columns[i]].dtype.name == 'int64'):
        print("(1) ","NAME_COL: ",df.columns[i], " //TYPE: ", df[df.columns[i]].dtype.name, "//MAX_VAL: ",df[df.columns[i]].max(), "//MIN_VAL: ",df[df.columns[i]].min(), "//MEDIA: ",df[df.columns[i]].mean(), "//MEDIANA: ",df[df.columns[i]].median(), "//CURTOSIS: ", df[df.columns[i]].kurt())
    else:
        print("(2) ","NAME_COL: ",df.columns[i], " //TYPE: ", df[df.columns[i]].dtype.name)
# Out:
# (2)  NAME_COL:  hotel  //TYPE:  object
# (1)  NAME_COL:  is_canceled  //TYPE:  int64 //MAX_VAL:  1 //MIN_VAL:  0 //MEDIA:  0.37041628277075134 //MEDIANA:  0.0 //CURTOSIS:  -1.7120049858378619
# (1)  NAME_COL:  lead_time  //TYPE:  int64 //MAX_VAL:  737 //MIN_VAL:  0 //MEDIA:  104.01141636652986 //MEDIANA:  69.0 //CURTOSIS:  1.6964488485585467
# (1)  NAME_COL:  arrival_date_year  //TYPE:  int64 //MAX_VAL:  2017 //MIN_VAL:  2015 //MEDIA:  2016.156554150264 //MEDIANA:  2016.0 //CURTOSIS:  -0.9945637526390856
# (2)  NAME_COL:  arrival_date_month  //TYPE:  object
# (1)  NAME_COL:  arrival_date_week_number  //TYPE:  int64 //MAX_VAL:  53 //MIN_VAL:  1 //MEDIA:  27.16517296255968 //MEDIANA:  28.0 //CURTOSIS:  -0.9860771763295451
# (1)  NAME_COL:  arrival_date_day_of_month  //TYPE:  int64 //MAX_VAL:  31 //MIN_VAL:  1 //MEDIA:  15.798241058715135 //MEDIANA:  16.0 //CURTOSIS:  -1.1871683187282633
# ...

# %%
df_object = df.select_dtypes(include=['int64','float64'])
df_object
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df_num = df.select_dtypes(exclude=['int64','float64'])
df_num
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 119385    City Hotel             August   BB     BEL  Offline TA/TO
# 119386    City Hotel             August   BB     FRA      Online TA
# 119387    City Hotel             August   BB     DEU      Online TA
# 119388    City Hotel             August   BB     GBR      Online TA
# 119389    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
def sep_col_string_and_num(df):
    for i in range(len(df.columns)):
        #print(df.columns[i], " - ", df[df.columns[i]].dtype.name)
        if(df[df.columns[i]].dtype.name == 'int64' or df[df.columns[i]].dtype.name == 'int64'):
            print("(1) ","NAME_COL: ",df.columns[i], " //TYPE: ", df[df.columns[i]].dtype.name, "//MAX_VAL: ",df[df.columns[i]].max(), "//MIN_VAL: ",df[df.columns[i]].min(), "//MEDIA: ",df[df.columns[i]].mean(), "//MEDIANA: ",df[df.columns[i]].median(), "//CURTOSIS: ", df[df.columns[i]].kurt())
        else:
            print("(2) ","NAME_COL: ",df.columns[i], " //TYPE: ", df[df.columns[i]].dtype.name)

# %%
sep_col_string_and_num(df)
# Out:
# (2)  NAME_COL:  hotel  //TYPE:  object
# (1)  NAME_COL:  is_canceled  //TYPE:  int64 //MAX_VAL:  1 //MIN_VAL:  0 //MEDIA:  0.37041628277075134 //MEDIANA:  0.0 //CURTOSIS:  -1.7120049858378619
# (1)  NAME_COL:  lead_time  //TYPE:  int64 //MAX_VAL:  737 //MIN_VAL:  0 //MEDIA:  104.01141636652986 //MEDIANA:  69.0 //CURTOSIS:  1.6964488485585467
# (1)  NAME_COL:  arrival_date_year  //TYPE:  int64 //MAX_VAL:  2017 //MIN_VAL:  2015 //MEDIA:  2016.156554150264 //MEDIANA:  2016.0 //CURTOSIS:  -0.9945637526390856
# (2)  NAME_COL:  arrival_date_month  //TYPE:  object
# (1)  NAME_COL:  arrival_date_week_number  //TYPE:  int64 //MAX_VAL:  53 //MIN_VAL:  1 //MEDIA:  27.16517296255968 //MEDIANA:  28.0 //CURTOSIS:  -0.9860771763295451
# (1)  NAME_COL:  arrival_date_day_of_month  //TYPE:  int64 //MAX_VAL:  31 //MIN_VAL:  1 //MEDIA:  15.798241058715135 //MEDIANA:  16.0 //CURTOSIS:  -1.1871683187282633
# ...

# %%
for i in range(len(df.columns)):
    print(df.columns[i], " - ", df[df.columns[i]].dtype.name)
# Out:
# hotel  -  object
# is_canceled  -  int64
# lead_time  -  int64
# arrival_date_year  -  int64
# arrival_date_month  -  object
# arrival_date_week_number  -  int64
# arrival_date_day_of_month  -  int64
# stays_in_weekend_nights  -  int64
# stays_in_week_nights  -  int64
# adults  -  int64
# children  -  float64
# babies  -  int64
# meal  -  object
# country  -  object
# market_segment  -  object
# distribution_channel  -  object
# is_repeated_guest  -  int64
# previous_cancellations  -  int64
# previous_bookings_not_canceled  -  int64
# reserved_room_type  -  object
# assigned_room_type  -  object
# booking_changes  -  int64
# deposit_type  -  object
# agent  -  float64
# company  -  float64
# days_in_waiting_list  -  int64
# customer_type  -  object
# adr  -  float64
# required_car_parking_spaces  -  int64
# total_of_special_requests  -  int64
# reservation_status  -  object
# reservation_status_date  -  object
